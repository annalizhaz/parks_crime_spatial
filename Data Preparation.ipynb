# %%
import pandas as pd
import geopandas as gpd

# %% [markdown]
# ### Remove Duplicate Shapes and Shapes without Population

# %%
pop_df = pd.read_csv("Data/Population_by_2010_Census_Block.csv", header = 0)

# %%
blocks = gpd.read_file("Data/blocks_original/blocks.shp")

# %%
valid_tracts = set(pop_df["CENSUS BLOCK"])

# %%
len(blocks)

# %%
passed_ids = set([])
new_gdf = []
new_df = []
missing_pop = []

for i, row in blocks.iterrows():
    if row["tract_bloc"] not in passed_ids and int(row["tract_bloc"]) in valid_tracts:
        passed_ids.add(row["tract_bloc"])
        new_gdf.append(row)
    elif row["tract_bloc"] in passed_ids:
        print("Row " + str(i) + " is a duplicate")
    if row["tract_bloc"] not in valid_tracts:
        missing_pop.append(row)
        print("Row " + str(i) + " has no population data")

# %%
blocks = blocks.GeoDataFrame(new_gdf, columns = list(gdf.columns))

# %%
len(blocks)

# %%
blocks.to_file(driver="ESRI Shapefile", filename = "Data/blocks_cleaned/blocks.shp")

# %% [markdown]
# Merged with population file in GeoDa

# %% [markdown]
# ### Spatial Join with Parks

# %%
blocks = gpd.read_file("Data/blocks_cleaned/blocks.shp")
parks = gpd.read_file("Data/parks_orig/parks.shp")

# %%
len(blocks)

# %%
bp = gpd.sjoin(blocks, parks, how="left", op='intersects')

# %%
len(bp)
# Out:
# 46334

# %%
passed_ids = set([])
new_gdf = []
new_df = []
missing_pop = []

for i, row in bp.iterrows():
    if row["tract_bloc"] not in passed_ids:
        passed_ids.add(row["tract_bloc"])
        new_gdf.append(row)
        
bp = gpd.GeoDataFrame(new_gdf, columns = list(blocks_with_parks.columns))

# %%
len(bp)

# %%
has_park = []
has_park_null = []
for i, row in bp.iterrows():
    if pd.notnull(row['index_right']):
        has_park.append(1)
        has_park_null.append(1)
    else:
        has_park.append(0)
        has_park_null.append(None)
        
blocks["has_park"] = has_park

# %%
blocks.to_file(driver="ESRI Shapefile", filename = "Data/blocks_and_parks/bp.shp")

# %% [markdown]
# ### Adding Crime Points

# %%
crime = gpd.read_file("Data/crime_original/crime.shp")
blocks = gpd.read_file("Data/blocks_and_parks/bp.shp")

# %%
crime_join = gpd.sjoin(crime, bp, how="left", op="within")
# Out:
# Warning: CRS does not match!

# %%
count = crime_match.groupby('tract_bloc').size()
crime_df = count.to_frame()
crime_df.reset_index(level=0, inplace=True)
crime_df = crime_df.rename(index=str, columns={0: "crime_count"})
crime_gdf = gpd.GeoDataFrame(crime_df)

# %%
bpc = bp.merge(crime_df, on="tract_bloc")

# %%
bpc.to_file(driver="ESRI Shapefile", filename = "Data/blocks_parks_crimes/bpc.shp")

# %% [markdown]
# ### Calculate Disctance to Nearest Park for Every Block

# %%
blocks = gpd.read_file("Data/BlocksParksCrimes/bpc.shp")
parks = gpd.read_file("Data/parks_final/parks_final.shp")

# %% [markdown]
# Warning: The following takes an extremely long time to run

# %%
blocks['min_dist_to_park'] = blocks.geometry.apply(lambda g: parks.distance(g).min())

# %%
blocks.to_file(driver="ESRI Shapefile", filename = "Data/test_parkdistance/parkdist.shp")

# %% [markdown]
# ### Calculate Block Area

# %%
blocks = gpd.read_file("Data/final_data/final_data.shp")

# %%
blocks["Area"] = blocks.area

# %%
blocks.to_file("Data/final_area/final_area.shp")

# %% [markdown]
# ### Assign Blocks to Community Area

# %%
blocks = gpd.read_file("Data/final_area/final_area.shp")

# %%
ca = gpd.read_file("ComArea/ComArea_ACS14_f.shp")

# %%
blocks_with_ca = gpd.sjoin(blocks, ca, how="left", op='intersects')

# %%
passed_ids = set([])
new_gdf = []
new_df = []

for i, row in blocks_with_ca.iterrows():
    if row["tract_bloc"] not in passed_ids and int(row["tract_bloc"]):
        passed_ids.add(row["tract_bloc"])
        new_gdf.append(row)
    else:
        print("Row " + str(i) + " is a duplicate")
# Out:
# Row 9 is a duplicate
# Row 10 is a duplicate
# Row 46 is a duplicate
# Row 59 is a duplicate
# Row 103 is a duplicate
# Row 103 is a duplicate
# Row 124 is a duplicate
# Row 148 is a duplicate
# Row 148 is a duplicate
# Row 149 is a duplicate
# Row 161 is a duplicate
# Row 163 is a duplicate
# Row 166 is a duplicate
# Row 171 is a duplicate
# Row 185 is a duplicate
# Row 189 is a duplicate
# Row 200 is a duplicate
# Row 221 is a duplicate
# Row 227 is a duplicate
# Row 229 is a duplicate
# Row 230 is a duplicate
# Row 265 is a duplicate
# Row 266 is a duplicate
# Row 286 is a duplicate
# Row 293 is a duplicate
# Row 307 is a duplicate
# Row 311 is a duplicate
# Row 347 is a duplicate
# Row 348 is a duplicate
# Row 349 is a duplicate
# Row 360 is a duplicate
# Row 430 is a duplicate
# Row 438 is a duplicate
# Row 445 is a duplicate
# Row 446 is a duplicate
# Row 466 is a duplicate
# Row 502 is a duplicate
# Row 509 is a duplicate
# Row 515 is a duplicate
# Row 515 is a duplicate
# Row 515 is a duplicate
# Row 545 is a duplicate
# Row 565 is a duplicate
# Row 574 is a duplicate
# Row 577 is a duplicate
# Row 586 is a duplicate
# Row 594 is a duplicate
# Row 596 is a duplicate
# Row 596 is a duplicate
# Row 606 is a duplicate
# Row 608 is a duplicate
# Row 612 is a duplicate
# Row 618 is a duplicate
# Row 626 is a duplicate
# Row 628 is a duplicate
# Row 645 is a duplicate
# Row 647 is a duplicate
# Row 657 is a duplicate
# Row 677 is a duplicate
# Row 684 is a duplicate
# Row 737 is a duplicate
# Row 755 is a duplicate
# Row 841 is a duplicate
# Row 842 is a duplicate
# Row 843 is a duplicate
# Row 861 is a duplicate
# Row 862 is a duplicate
# Row 871 is a duplicate
# Row 875 is a duplicate
# Row 877 is a duplicate
# Row 881 is a duplicate
# Row 882 is a duplicate
# Row 890 is a duplicate
# Row 896 is a duplicate
# Row 900 is a duplicate
# Row 913 is a duplicate
# Row 918 is a duplicate
# Row 921 is a duplicate
# Row 928 is a duplicate
# Row 929 is a duplicate
# Row 940 is a duplicate
# Row 948 is a duplicate
# Row 961 is a duplicate
# Row 975 is a duplicate
# Row 987 is a duplicate
# Row 989 is a duplicate
# Row 989 is a duplicate
# Row 991 is a duplicate
# Row 995 is a duplicate
# Row 1013 is a duplicate
# Row 1020 is a duplicate
# Row 1022 is a duplicate
# Row 1028 is a duplicate
# Row 1032 is a duplicate
# Row 1051 is a duplicate
# Row 1080 is a duplicate
# Row 1089 is a duplicate
# Row 1095 is a duplicate
# Row 1105 is a duplicate
# Row 1115 is a duplicate
# Row 1118 is a duplicate
# Row 1146 is a duplicate
# Row 1147 is a duplicate
# Row 1148 is a duplicate
# Row 1175 is a duplicate
# Row 1205 is a duplicate
# Row 1210 is a duplicate
# Row 1220 is a duplicate
# Row 1242 is a duplicate
# Row 1248 is a duplicate
# Row 1258 is a duplicate
# Row 1262 is a duplicate
# Row 1282 is a duplicate
# Row 1301 is a duplicate
# Row 1302 is a duplicate
# Row 1305 is a duplicate
# Row 1308 is a duplicate
# Row 1315 is a duplicate
# Row 1343 is a duplicate
# Row 1354 is a duplicate
# Row 1367 is a duplicate
# Row 1388 is a duplicate
# Row 1402 is a duplicate
# Row 1412 is a duplicate
# Row 1422 is a duplicate
# Row 1426 is a duplicate
# Row 1433 is a duplicate
# Row 1437 is a duplicate
# Row 1439 is a duplicate
# Row 1445 is a duplicate
# Row 1446 is a duplicate
# Row 1449 is a duplicate
# Row 1451 is a duplicate
# Row 1454 is a duplicate
# Row 1461 is a duplicate
# Row 1484 is a duplicate
# Row 1484 is a duplicate
# Row 1539 is a duplicate
# Row 1545 is a duplicate
# Row 1563 is a duplicate
# Row 1570 is a duplicate
# Row 1599 is a duplicate
# Row 1606 is a duplicate
# Row 1613 is a duplicate
# Row 1614 is a duplicate
# Row 1643 is a duplicate
# Row 1647 is a duplicate
# Row 1648 is a duplicate
# Row 1662 is a duplicate
# Row 1666 is a duplicate
# Row 1668 is a duplicate
# Row 1693 is a duplicate
# Row 1709 is a duplicate
# Row 1713 is a duplicate
# Row 1725 is a duplicate
# Row 1789 is a duplicate
# Row 1790 is a duplicate
# Row 1791 is a duplicate
# Row 1793 is a duplicate
# Row 1797 is a duplicate
# Row 1819 is a duplicate
# Row 1822 is a duplicate
# Row 1833 is a duplicate
# Row 1885 is a duplicate
# Row 1888 is a duplicate
# Row 1890 is a duplicate
# Row 1890 is a duplicate
# Row 1894 is a duplicate
# Row 1913 is a duplicate
# Row 1920 is a duplicate
# Row 1935 is a duplicate
# Row 1951 is a duplicate
# Row 1964 is a duplicate
# Row 1967 is a duplicate
# Row 1972 is a duplicate
# Row 2004 is a duplicate
# Row 2008 is a duplicate
# Row 2020 is a duplicate
# Row 2027 is a duplicate
# Row 2030 is a duplicate
# Row 2035 is a duplicate
# Row 2036 is a duplicate
# Row 2038 is a duplicate
# Row 2039 is a duplicate
# Row 2053 is a duplicate
# Row 2065 is a duplicate
# Row 2070 is a duplicate
# Row 2071 is a duplicate
# Row 2094 is a duplicate
# Row 2096 is a duplicate
# Row 2144 is a duplicate
# Row 2154 is a duplicate
# Row 2170 is a duplicate
# Row 2181 is a duplicate
# Row 2186 is a duplicate
# Row 2187 is a duplicate
# Row 2205 is a duplicate
# Row 2212 is a duplicate
# Row 2218 is a duplicate
# Row 2223 is a duplicate
# Row 2224 is a duplicate
# Row 2265 is a duplicate
# Row 2266 is a duplicate
# Row 2272 is a duplicate
# Row 2292 is a duplicate
# Row 2329 is a duplicate
# Row 2330 is a duplicate
# Row 2331 is a duplicate
# Row 2391 is a duplicate
# Row 2407 is a duplicate
# Row 2433 is a duplicate
# Row 2438 is a duplicate
# Row 2453 is a duplicate
# Row 2454 is a duplicate
# Row 2456 is a duplicate
# Row 2471 is a duplicate
# Row 2485 is a duplicate
# Row 2495 is a duplicate
# Row 2528 is a duplicate
# Row 2534 is a duplicate
# Row 2544 is a duplicate
# Row 2572 is a duplicate
# Row 2574 is a duplicate
# Row 2575 is a duplicate
# Row 2585 is a duplicate
# Row 2608 is a duplicate
# Row 2625 is a duplicate
# Row 2627 is a duplicate
# Row 2628 is a duplicate
# Row 2644 is a duplicate
# Row 2645 is a duplicate
# Row 2645 is a duplicate
# Row 2652 is a duplicate
# Row 2670 is a duplicate
# Row 2671 is a duplicate
# Row 2683 is a duplicate
# Row 2687 is a duplicate
# Row 2695 is a duplicate
# Row 2696 is a duplicate
# Row 2701 is a duplicate
# Row 2704 is a duplicate
# Row 2708 is a duplicate
# Row 2715 is a duplicate
# Row 2717 is a duplicate
# Row 2718 is a duplicate
# Row 2730 is a duplicate
# Row 2829 is a duplicate
# Row 2830 is a duplicate
# Row 2853 is a duplicate
# Row 2873 is a duplicate
# Row 2874 is a duplicate
# Row 2879 is a duplicate
# Row 2882 is a duplicate
# Row 2893 is a duplicate
# Row 2927 is a duplicate
# Row 2954 is a duplicate
# Row 2955 is a duplicate
# Row 2962 is a duplicate
# Row 2962 is a duplicate
# Row 2974 is a duplicate
# Row 2988 is a duplicate
# Row 2999 is a duplicate
# Row 3000 is a duplicate
# Row 3011 is a duplicate
# Row 3046 is a duplicate
# Row 3049 is a duplicate
# Row 3065 is a duplicate
# Row 3070 is a duplicate
# Row 3072 is a duplicate
# Row 3103 is a duplicate
# Row 3104 is a duplicate
# Row 3110 is a duplicate
# Row 3123 is a duplicate
# Row 3164 is a duplicate
# Row 3172 is a duplicate
# Row 3238 is a duplicate
# Row 3246 is a duplicate
# Row 3262 is a duplicate
# Row 3273 is a duplicate
# Row 3280 is a duplicate
# Row 3292 is a duplicate
# Row 3297 is a duplicate
# Row 3298 is a duplicate
# Row 3301 is a duplicate
# Row 3303 is a duplicate
# Row 3304 is a duplicate
# Row 3316 is a duplicate
# Row 3357 is a duplicate
# Row 3378 is a duplicate
# Row 3392 is a duplicate
# Row 3398 is a duplicate
# Row 3399 is a duplicate
# Row 3405 is a duplicate
# Row 3406 is a duplicate
# Row 3419 is a duplicate
# Row 3426 is a duplicate
# Row 3434 is a duplicate
# Row 3477 is a duplicate
# Row 3527 is a duplicate
# Row 3538 is a duplicate
# Row 3577 is a duplicate
# Row 3589 is a duplicate
# Row 3592 is a duplicate
# Row 3616 is a duplicate
# Row 3626 is a duplicate
# Row 3627 is a duplicate
# Row 3647 is a duplicate
# Row 3664 is a duplicate
# Row 3664 is a duplicate
# Row 3670 is a duplicate
# Row 3683 is a duplicate
# Row 3687 is a duplicate
# Row 3694 is a duplicate
# Row 3701 is a duplicate
# Row 3705 is a duplicate
# Row 3706 is a duplicate
# Row 3718 is a duplicate
# Row 3739 is a duplicate
# Row 3740 is a duplicate
# Row 3741 is a duplicate
# Row 3741 is a duplicate
# Row 3754 is a duplicate
# Row 3758 is a duplicate
# Row 3799 is a duplicate
# Row 3805 is a duplicate
# Row 3806 is a duplicate
# Row 3818 is a duplicate
# Row 3874 is a duplicate
# Row 3875 is a duplicate
# Row 3878 is a duplicate
# Row 3889 is a duplicate
# Row 3896 is a duplicate
# Row 3897 is a duplicate
# Row 3901 is a duplicate
# Row 3906 is a duplicate
# Row 3906 is a duplicate
# Row 3907 is a duplicate
# Row 3907 is a duplicate
# Row 3910 is a duplicate
# Row 3923 is a duplicate
# Row 3930 is a duplicate
# Row 3931 is a duplicate
# Row 3931 is a duplicate
# Row 3970 is a duplicate
# Row 3971 is a duplicate
# Row 3998 is a duplicate
# Row 4020 is a duplicate
# Row 4029 is a duplicate
# Row 4038 is a duplicate
# Row 4041 is a duplicate
# Row 4052 is a duplicate
# Row 4062 is a duplicate
# Row 4065 is a duplicate
# Row 4071 is a duplicate
# Row 4071 is a duplicate
# Row 4082 is a duplicate
# Row 4090 is a duplicate
# Row 4116 is a duplicate
# Row 4122 is a duplicate
# Row 4134 is a duplicate
# Row 4136 is a duplicate
# Row 4137 is a duplicate
# Row 4138 is a duplicate
# Row 4139 is a duplicate
# Row 4140 is a duplicate
# Row 4142 is a duplicate
# Row 4177 is a duplicate
# Row 4182 is a duplicate
# Row 4187 is a duplicate
# Row 4194 is a duplicate
# Row 4195 is a duplicate
# Row 4200 is a duplicate
# Row 4213 is a duplicate
# Row 4214 is a duplicate
# Row 4217 is a duplicate
# Row 4226 is a duplicate
# Row 4226 is a duplicate
# Row 4246 is a duplicate
# Row 4246 is a duplicate
# Row 4250 is a duplicate
# Row 4261 is a duplicate
# Row 4261 is a duplicate
# Row 4270 is a duplicate
# Row 4279 is a duplicate
# Row 4280 is a duplicate
# Row 4285 is a duplicate
# Row 4297 is a duplicate
# Row 4312 is a duplicate
# Row 4326 is a duplicate
# Row 4334 is a duplicate
# Row 4352 is a duplicate
# Row 4378 is a duplicate
# Row 4379 is a duplicate
# Row 4383 is a duplicate
# Row 4387 is a duplicate
# Row 4389 is a duplicate
# Row 4402 is a duplicate
# Row 4403 is a duplicate
# Row 4405 is a duplicate
# Row 4406 is a duplicate
# Row 4407 is a duplicate
# Row 4409 is a duplicate
# Row 4410 is a duplicate
# Row 4415 is a duplicate
# Row 4417 is a duplicate
# Row 4421 is a duplicate
# Row 4422 is a duplicate
# Row 4422 is a duplicate
# Row 4423 is a duplicate
# Row 4424 is a duplicate
# Row 4425 is a duplicate
# Row 4445 is a duplicate
# Row 4447 is a duplicate
# Row 4450 is a duplicate
# Row 4454 is a duplicate
# Row 4455 is a duplicate
# Row 4474 is a duplicate
# Row 4475 is a duplicate
# Row 4477 is a duplicate
# Row 4486 is a duplicate
# Row 4489 is a duplicate
# Row 4491 is a duplicate
# Row 4505 is a duplicate
# Row 4516 is a duplicate
# Row 4517 is a duplicate
# Row 4517 is a duplicate
# Row 4522 is a duplicate
# Row 4534 is a duplicate
# Row 4543 is a duplicate
# Row 4543 is a duplicate
# Row 4570 is a duplicate
# Row 4585 is a duplicate
# Row 4590 is a duplicate
# Row 4596 is a duplicate
# Row 4604 is a duplicate
# Row 4629 is a duplicate
# Row 4637 is a duplicate
# Row 4639 is a duplicate
# Row 4640 is a duplicate
# Row 4642 is a duplicate
# Row 4649 is a duplicate
# Row 4650 is a duplicate
# Row 4689 is a duplicate
# Row 4699 is a duplicate
# Row 4711 is a duplicate
# Row 4712 is a duplicate
# Row 4712 is a duplicate
# Row 4720 is a duplicate
# Row 4721 is a duplicate
# Row 4725 is a duplicate
# Row 4727 is a duplicate
# Row 4736 is a duplicate
# Row 4749 is a duplicate
# Row 4758 is a duplicate
# Row 4759 is a duplicate
# Row 4797 is a duplicate
# Row 4810 is a duplicate
# Row 4818 is a duplicate
# Row 4833 is a duplicate
# Row 4839 is a duplicate
# Row 4841 is a duplicate
# Row 4867 is a duplicate
# Row 4869 is a duplicate
# Row 4882 is a duplicate
# Row 4895 is a duplicate
# Row 4902 is a duplicate
# Row 4907 is a duplicate
# Row 4937 is a duplicate
# Row 4946 is a duplicate
# Row 4946 is a duplicate
# Row 4947 is a duplicate
# Row 4979 is a duplicate
# Row 4980 is a duplicate
# Row 4994 is a duplicate
# Row 5015 is a duplicate
# Row 5033 is a duplicate
# Row 5034 is a duplicate
# Row 5050 is a duplicate
# Row 5074 is a duplicate
# Row 5082 is a duplicate
# Row 5084 is a duplicate
# Row 5089 is a duplicate
# Row 5097 is a duplicate
# Row 5104 is a duplicate
# Row 5112 is a duplicate
# Row 5115 is a duplicate
# Row 5124 is a duplicate
# Row 5130 is a duplicate
# Row 5162 is a duplicate
# Row 5163 is a duplicate
# Row 5168 is a duplicate
# Row 5172 is a duplicate
# Row 5183 is a duplicate
# Row 5184 is a duplicate
# Row 5187 is a duplicate
# Row 5188 is a duplicate
# Row 5189 is a duplicate
# Row 5195 is a duplicate
# Row 5204 is a duplicate
# Row 5206 is a duplicate
# Row 5212 is a duplicate
# Row 5231 is a duplicate
# Row 5245 is a duplicate
# Row 5278 is a duplicate
# Row 5280 is a duplicate
# Row 5282 is a duplicate
# Row 5335 is a duplicate
# Row 5335 is a duplicate
# Row 5349 is a duplicate
# Row 5350 is a duplicate
# Row 5355 is a duplicate
# Row 5356 is a duplicate
# Row 5356 is a duplicate
# Row 5360 is a duplicate
# Row 5361 is a duplicate
# Row 5378 is a duplicate
# Row 5380 is a duplicate
# Row 5384 is a duplicate
# Row 5386 is a duplicate
# Row 5389 is a duplicate
# Row 5418 is a duplicate
# Row 5421 is a duplicate
# Row 5426 is a duplicate
# Row 5432 is a duplicate
# Row 5438 is a duplicate
# Row 5445 is a duplicate
# Row 5451 is a duplicate
# Row 5461 is a duplicate
# Row 5462 is a duplicate
# Row 5482 is a duplicate
# Row 5484 is a duplicate
# Row 5501 is a duplicate
# Row 5514 is a duplicate
# Row 5526 is a duplicate
# Row 5532 is a duplicate
# Row 5538 is a duplicate
# Row 5539 is a duplicate
# Row 5554 is a duplicate
# Row 5559 is a duplicate
# Row 5617 is a duplicate
# Row 5628 is a duplicate
# Row 5628 is a duplicate
# Row 5647 is a duplicate
# Row 5647 is a duplicate
# Row 5651 is a duplicate
# Row 5657 is a duplicate
# Row 5660 is a duplicate
# Row 5662 is a duplicate
# Row 5663 is a duplicate
# Row 5665 is a duplicate
# Row 5671 is a duplicate
# Row 5672 is a duplicate
# Row 5674 is a duplicate
# Row 5681 is a duplicate
# Row 5685 is a duplicate
# Row 5694 is a duplicate
# Row 5696 is a duplicate
# Row 5699 is a duplicate
# Row 5700 is a duplicate
# Row 5703 is a duplicate
# Row 5705 is a duplicate
# Row 5719 is a duplicate
# Row 5747 is a duplicate
# Row 5748 is a duplicate
# Row 5778 is a duplicate
# Row 5833 is a duplicate
# Row 5874 is a duplicate
# Row 5880 is a duplicate
# Row 5881 is a duplicate
# Row 5883 is a duplicate
# Row 5885 is a duplicate
# Row 5886 is a duplicate
# Row 5886 is a duplicate
# Row 5887 is a duplicate
# Row 5890 is a duplicate
# Row 5902 is a duplicate
# Row 5914 is a duplicate
# Row 5922 is a duplicate
# Row 5931 is a duplicate
# Row 5942 is a duplicate
# Row 5945 is a duplicate
# Row 5950 is a duplicate
# Row 5963 is a duplicate
# Row 5964 is a duplicate
# Row 5967 is a duplicate
# Row 5983 is a duplicate
# Row 5991 is a duplicate
# Row 6026 is a duplicate
# Row 6029 is a duplicate
# Row 6052 is a duplicate
# Row 6057 is a duplicate
# Row 6060 is a duplicate
# Row 6069 is a duplicate
# Row 6088 is a duplicate
# Row 6088 is a duplicate
# Row 6089 is a duplicate
# Row 6112 is a duplicate
# Row 6112 is a duplicate
# Row 6112 is a duplicate
# Row 6159 is a duplicate
# Row 6164 is a duplicate
# Row 6236 is a duplicate
# Row 6249 is a duplicate
# Row 6303 is a duplicate
# Row 6399 is a duplicate
# Row 6401 is a duplicate
# Row 6414 is a duplicate
# Row 6463 is a duplicate
# Row 6470 is a duplicate
# Row 6506 is a duplicate
# Row 6530 is a duplicate
# Row 6540 is a duplicate
# Row 6543 is a duplicate
# Row 6555 is a duplicate
# Row 6565 is a duplicate
# Row 6592 is a duplicate
# Row 6599 is a duplicate
# Row 6600 is a duplicate
# Row 6617 is a duplicate
# Row 6629 is a duplicate
# Row 6641 is a duplicate
# Row 6645 is a duplicate
# Row 6670 is a duplicate
# Row 6696 is a duplicate
# Row 6697 is a duplicate
# Row 6700 is a duplicate
# Row 6704 is a duplicate
# Row 6707 is a duplicate
# Row 6714 is a duplicate
# Row 6741 is a duplicate
# Row 6749 is a duplicate
# Row 6776 is a duplicate
# Row 6797 is a duplicate
# Row 6808 is a duplicate
# Row 6833 is a duplicate
# Row 6842 is a duplicate
# Row 6847 is a duplicate
# Row 6858 is a duplicate
# Row 6860 is a duplicate
# Row 6861 is a duplicate
# Row 6879 is a duplicate
# Row 6880 is a duplicate
# Row 6927 is a duplicate
# Row 6932 is a duplicate
# Row 6945 is a duplicate
# Row 6958 is a duplicate
# Row 6961 is a duplicate
# Row 6971 is a duplicate
# Row 7000 is a duplicate
# Row 7022 is a duplicate
# Row 7041 is a duplicate
# Row 7056 is a duplicate
# Row 7073 is a duplicate
# Row 7086 is a duplicate
# Row 7088 is a duplicate
# Row 7088 is a duplicate
# Row 7096 is a duplicate
# Row 7104 is a duplicate
# Row 7119 is a duplicate
# Row 7131 is a duplicate
# Row 7138 is a duplicate
# Row 7143 is a duplicate
# Row 7162 is a duplicate
# Row 7186 is a duplicate
# Row 7210 is a duplicate
# Row 7211 is a duplicate
# Row 7212 is a duplicate
# Row 7218 is a duplicate
# Row 7233 is a duplicate
# Row 7239 is a duplicate
# Row 7251 is a duplicate
# Row 7257 is a duplicate
# Row 7302 is a duplicate
# Row 7338 is a duplicate
# Row 7349 is a duplicate
# Row 7352 is a duplicate
# Row 7360 is a duplicate
# Row 7367 is a duplicate
# Row 7368 is a duplicate
# Row 7376 is a duplicate
# Row 7380 is a duplicate
# Row 7391 is a duplicate
# Row 7399 is a duplicate
# Row 7407 is a duplicate
# Row 7414 is a duplicate
# Row 7427 is a duplicate
# Row 7441 is a duplicate
# Row 7447 is a duplicate
# Row 7448 is a duplicate
# Row 7452 is a duplicate
# Row 7487 is a duplicate
# Row 7488 is a duplicate
# Row 7489 is a duplicate
# Row 7519 is a duplicate
# Row 7536 is a duplicate
# Row 7580 is a duplicate
# Row 7582 is a duplicate
# Row 7587 is a duplicate
# Row 7595 is a duplicate
# Row 7595 is a duplicate
# Row 7598 is a duplicate
# Row 7599 is a duplicate
# Row 7602 is a duplicate
# Row 7610 is a duplicate
# Row 7616 is a duplicate
# Row 7625 is a duplicate
# Row 7645 is a duplicate
# Row 7651 is a duplicate
# Row 7668 is a duplicate
# Row 7680 is a duplicate
# Row 7684 is a duplicate
# Row 7703 is a duplicate
# Row 7704 is a duplicate
# Row 7723 is a duplicate
# Row 7724 is a duplicate
# Row 7745 is a duplicate
# Row 7754 is a duplicate
# Row 7801 is a duplicate
# Row 7813 is a duplicate
# Row 7842 is a duplicate
# Row 7846 is a duplicate
# Row 7855 is a duplicate
# Row 7872 is a duplicate
# Row 7890 is a duplicate
# Row 7893 is a duplicate
# Row 7901 is a duplicate
# Row 7908 is a duplicate
# Row 7918 is a duplicate
# Row 7939 is a duplicate
# Row 7942 is a duplicate
# Row 7944 is a duplicate
# Row 7960 is a duplicate
# Row 7973 is a duplicate
# Row 8002 is a duplicate
# Row 8007 is a duplicate
# Row 8008 is a duplicate
# Row 8009 is a duplicate
# Row 8010 is a duplicate
# Row 8016 is a duplicate
# Row 8018 is a duplicate
# Row 8033 is a duplicate
# Row 8033 is a duplicate
# Row 8038 is a duplicate
# Row 8046 is a duplicate
# Row 8046 is a duplicate
# Row 8059 is a duplicate
# Row 8070 is a duplicate
# Row 8072 is a duplicate
# Row 8072 is a duplicate
# Row 8076 is a duplicate
# Row 8094 is a duplicate
# Row 8103 is a duplicate
# Row 8104 is a duplicate
# Row 8151 is a duplicate
# Row 8174 is a duplicate
# Row 8190 is a duplicate
# Row 8200 is a duplicate
# Row 8201 is a duplicate
# Row 8202 is a duplicate
# Row 8237 is a duplicate
# Row 8248 is a duplicate
# Row 8259 is a duplicate
# Row 8264 is a duplicate
# Row 8277 is a duplicate
# Row 8289 is a duplicate
# Row 8303 is a duplicate
# Row 8349 is a duplicate
# Row 8353 is a duplicate
# Row 8397 is a duplicate
# Row 8410 is a duplicate
# Row 8416 is a duplicate
# Row 8424 is a duplicate
# Row 8438 is a duplicate
# Row 8457 is a duplicate
# Row 8458 is a duplicate
# Row 8462 is a duplicate
# Row 8499 is a duplicate
# Row 8509 is a duplicate
# Row 8510 is a duplicate
# Row 8574 is a duplicate
# Row 8620 is a duplicate
# Row 8620 is a duplicate
# Row 8621 is a duplicate
# Row 8624 is a duplicate
# Row 8628 is a duplicate
# Row 8639 is a duplicate
# Row 8724 is a duplicate
# Row 8740 is a duplicate
# Row 8750 is a duplicate
# Row 8752 is a duplicate
# Row 8760 is a duplicate
# Row 8769 is a duplicate
# Row 8797 is a duplicate
# Row 8803 is a duplicate
# Row 8814 is a duplicate
# Row 8816 is a duplicate
# Row 8840 is a duplicate
# Row 8854 is a duplicate
# Row 8857 is a duplicate
# Row 8859 is a duplicate
# Row 8866 is a duplicate
# Row 8869 is a duplicate
# Row 8870 is a duplicate
# Row 8871 is a duplicate
# Row 8879 is a duplicate
# Row 8883 is a duplicate
# Row 8901 is a duplicate
# Row 8970 is a duplicate
# Row 8971 is a duplicate
# Row 8978 is a duplicate
# Row 8980 is a duplicate
# Row 8981 is a duplicate
# Row 8983 is a duplicate
# Row 8984 is a duplicate
# Row 8987 is a duplicate
# Row 8988 is a duplicate
# Row 8995 is a duplicate
# Row 8998 is a duplicate
# Row 9003 is a duplicate
# Row 9004 is a duplicate
# Row 9005 is a duplicate
# Row 9010 is a duplicate
# Row 9048 is a duplicate
# Row 9053 is a duplicate
# Row 9071 is a duplicate
# Row 9082 is a duplicate
# Row 9112 is a duplicate
# Row 9116 is a duplicate
# Row 9123 is a duplicate
# Row 9139 is a duplicate
# Row 9140 is a duplicate
# Row 9149 is a duplicate
# Row 9161 is a duplicate
# Row 9163 is a duplicate
# Row 9164 is a duplicate
# Row 9165 is a duplicate
# Row 9171 is a duplicate
# Row 9173 is a duplicate
# Row 9180 is a duplicate
# Row 9186 is a duplicate
# Row 9191 is a duplicate
# Row 9202 is a duplicate
# Row 9231 is a duplicate
# Row 9237 is a duplicate
# Row 9260 is a duplicate
# Row 9264 is a duplicate
# Row 9273 is a duplicate
# Row 9283 is a duplicate
# Row 9284 is a duplicate
# Row 9291 is a duplicate
# Row 9291 is a duplicate
# Row 9292 is a duplicate
# Row 9294 is a duplicate
# Row 9304 is a duplicate
# Row 9305 is a duplicate
# Row 9310 is a duplicate
# Row 9333 is a duplicate
# Row 9372 is a duplicate
# Row 9449 is a duplicate
# Row 9460 is a duplicate
# Row 9461 is a duplicate
# Row 9479 is a duplicate
# Row 9485 is a duplicate
# Row 9493 is a duplicate
# Row 9494 is a duplicate
# Row 9499 is a duplicate
# Row 9500 is a duplicate
# Row 9534 is a duplicate
# Row 9560 is a duplicate
# Row 9618 is a duplicate
# Row 9619 is a duplicate
# Row 9643 is a duplicate
# Row 9670 is a duplicate
# Row 9702 is a duplicate
# Row 9702 is a duplicate
# Row 9705 is a duplicate
# Row 9731 is a duplicate
# Row 9781 is a duplicate
# Row 9791 is a duplicate
# Row 9803 is a duplicate
# Row 9807 is a duplicate
# Row 9818 is a duplicate
# Row 9854 is a duplicate
# Row 9865 is a duplicate
# Row 9875 is a duplicate
# Row 9883 is a duplicate
# Row 9927 is a duplicate
# Row 9928 is a duplicate
# Row 9929 is a duplicate
# Row 9931 is a duplicate
# Row 9942 is a duplicate
# Row 9946 is a duplicate
# Row 9968 is a duplicate
# Row 10010 is a duplicate
# Row 10011 is a duplicate
# Row 10012 is a duplicate
# Row 10016 is a duplicate
# Row 10023 is a duplicate
# Row 10040 is a duplicate
# Row 10057 is a duplicate
# Row 10063 is a duplicate
# Row 10068 is a duplicate
# Row 10075 is a duplicate
# Row 10076 is a duplicate
# Row 10081 is a duplicate
# Row 10100 is a duplicate
# Row 10120 is a duplicate
# Row 10121 is a duplicate
# Row 10122 is a duplicate
# Row 10151 is a duplicate
# Row 10152 is a duplicate
# Row 10167 is a duplicate
# Row 10214 is a duplicate
# Row 10216 is a duplicate
# Row 10219 is a duplicate
# Row 10231 is a duplicate
# Row 10238 is a duplicate
# Row 10279 is a duplicate
# Row 10281 is a duplicate
# Row 10284 is a duplicate
# Row 10287 is a duplicate
# Row 10290 is a duplicate
# Row 10290 is a duplicate
# Row 10291 is a duplicate
# Row 10295 is a duplicate
# Row 10295 is a duplicate
# Row 10303 is a duplicate
# Row 10324 is a duplicate
# Row 10332 is a duplicate
# Row 10333 is a duplicate
# Row 10341 is a duplicate
# Row 10351 is a duplicate
# Row 10352 is a duplicate
# Row 10353 is a duplicate
# Row 10356 is a duplicate
# Row 10358 is a duplicate
# Row 10362 is a duplicate
# Row 10370 is a duplicate
# Row 10371 is a duplicate
# Row 10383 is a duplicate
# Row 10383 is a duplicate
# Row 10406 is a duplicate
# Row 10412 is a duplicate
# Row 10417 is a duplicate
# Row 10417 is a duplicate
# Row 10418 is a duplicate
# Row 10424 is a duplicate
# Row 10430 is a duplicate
# Row 10432 is a duplicate
# Row 10434 is a duplicate
# Row 10438 is a duplicate
# Row 10494 is a duplicate
# Row 10495 is a duplicate
# Row 10575 is a duplicate
# Row 10576 is a duplicate
# Row 10580 is a duplicate
# Row 10602 is a duplicate
# Row 10606 is a duplicate
# Row 10606 is a duplicate
# Row 10632 is a duplicate
# Row 10642 is a duplicate
# Row 10642 is a duplicate
# Row 10644 is a duplicate
# Row 10654 is a duplicate
# Row 10658 is a duplicate
# Row 10659 is a duplicate
# Row 10664 is a duplicate
# Row 10666 is a duplicate
# Row 10675 is a duplicate
# Row 10676 is a duplicate
# Row 10685 is a duplicate
# Row 10693 is a duplicate
# Row 10733 is a duplicate
# Row 10795 is a duplicate
# Row 10800 is a duplicate
# Row 10821 is a duplicate
# Row 10828 is a duplicate
# Row 10837 is a duplicate
# Row 10848 is a duplicate
# Row 10880 is a duplicate
# Row 10883 is a duplicate
# Row 10891 is a duplicate
# Row 10900 is a duplicate
# Row 10900 is a duplicate
# Row 10906 is a duplicate
# Row 10908 is a duplicate
# Row 10908 is a duplicate
# Row 10912 is a duplicate
# Row 10913 is a duplicate
# Row 10924 is a duplicate
# Row 10929 is a duplicate
# Row 10942 is a duplicate
# Row 10966 is a duplicate
# Row 10986 is a duplicate
# Row 10996 is a duplicate
# Row 11010 is a duplicate
# Row 11013 is a duplicate
# Row 11015 is a duplicate
# Row 11028 is a duplicate
# Row 11048 is a duplicate
# Row 11052 is a duplicate
# Row 11109 is a duplicate
# Row 11116 is a duplicate
# Row 11117 is a duplicate
# Row 11135 is a duplicate
# Row 11159 is a duplicate
# Row 11172 is a duplicate
# Row 11198 is a duplicate
# Row 11217 is a duplicate
# Row 11219 is a duplicate
# Row 11222 is a duplicate
# Row 11223 is a duplicate
# Row 11233 is a duplicate
# Row 11239 is a duplicate
# Row 11313 is a duplicate
# Row 11338 is a duplicate
# Row 11346 is a duplicate
# Row 11376 is a duplicate
# Row 11381 is a duplicate
# Row 11383 is a duplicate
# Row 11387 is a duplicate
# Row 11390 is a duplicate
# Row 11420 is a duplicate
# Row 11432 is a duplicate
# Row 11483 is a duplicate
# Row 11486 is a duplicate
# Row 11487 is a duplicate
# Row 11503 is a duplicate
# Row 11503 is a duplicate
# Row 11511 is a duplicate
# Row 11524 is a duplicate
# Row 11525 is a duplicate
# Row 11528 is a duplicate
# Row 11529 is a duplicate
# Row 11552 is a duplicate
# Row 11561 is a duplicate
# Row 11562 is a duplicate
# Row 11570 is a duplicate
# Row 11576 is a duplicate
# Row 11578 is a duplicate
# Row 11586 is a duplicate
# Row 11612 is a duplicate
# Row 11646 is a duplicate
# Row 11649 is a duplicate
# Row 11693 is a duplicate
# Row 11695 is a duplicate
# Row 11701 is a duplicate
# Row 11702 is a duplicate
# Row 11709 is a duplicate
# Row 11728 is a duplicate
# Row 11741 is a duplicate
# Row 11759 is a duplicate
# Row 11768 is a duplicate
# Row 11781 is a duplicate
# Row 11791 is a duplicate
# Row 11795 is a duplicate
# Row 11807 is a duplicate
# Row 11809 is a duplicate
# Row 11812 is a duplicate
# Row 11832 is a duplicate
# Row 11843 is a duplicate
# Row 11859 is a duplicate
# Row 11860 is a duplicate
# Row 11864 is a duplicate
# Row 11901 is a duplicate
# Row 11921 is a duplicate
# Row 11925 is a duplicate
# Row 11927 is a duplicate
# Row 11928 is a duplicate
# Row 11938 is a duplicate
# Row 11946 is a duplicate
# Row 11953 is a duplicate
# Row 11991 is a duplicate
# Row 12000 is a duplicate
# Row 12001 is a duplicate
# Row 12048 is a duplicate
# Row 12063 is a duplicate
# Row 12070 is a duplicate
# Row 12074 is a duplicate
# Row 12092 is a duplicate
# Row 12096 is a duplicate
# Row 12110 is a duplicate
# Row 12128 is a duplicate
# Row 12131 is a duplicate
# Row 12139 is a duplicate
# Row 12140 is a duplicate
# Row 12141 is a duplicate
# Row 12160 is a duplicate
# Row 12161 is a duplicate
# Row 12182 is a duplicate
# Row 12203 is a duplicate
# Row 12207 is a duplicate
# Row 12215 is a duplicate
# Row 12230 is a duplicate
# Row 12236 is a duplicate
# Row 12240 is a duplicate
# Row 12241 is a duplicate
# Row 12244 is a duplicate
# Row 12248 is a duplicate
# Row 12254 is a duplicate
# Row 12255 is a duplicate
# Row 12271 is a duplicate
# Row 12273 is a duplicate
# Row 12274 is a duplicate
# Row 12278 is a duplicate
# Row 12280 is a duplicate
# Row 12281 is a duplicate
# Row 12284 is a duplicate
# Row 12326 is a duplicate
# Row 12339 is a duplicate
# Row 12347 is a duplicate
# Row 12348 is a duplicate
# Row 12349 is a duplicate
# Row 12356 is a duplicate
# Row 12358 is a duplicate
# Row 12368 is a duplicate
# Row 12381 is a duplicate
# Row 12388 is a duplicate
# Row 12390 is a duplicate
# Row 12391 is a duplicate
# Row 12461 is a duplicate
# Row 12473 is a duplicate
# Row 12488 is a duplicate
# Row 12508 is a duplicate
# Row 12519 is a duplicate
# Row 12538 is a duplicate
# Row 12541 is a duplicate
# Row 12542 is a duplicate
# Row 12564 is a duplicate
# Row 12566 is a duplicate
# Row 12571 is a duplicate
# Row 12574 is a duplicate
# Row 12581 is a duplicate
# Row 12598 is a duplicate
# Row 12614 is a duplicate
# Row 12626 is a duplicate
# Row 12663 is a duplicate
# Row 12664 is a duplicate
# Row 12680 is a duplicate
# Row 12693 is a duplicate
# Row 12694 is a duplicate
# Row 12739 is a duplicate
# Row 12749 is a duplicate
# Row 12753 is a duplicate
# Row 12755 is a duplicate
# Row 12766 is a duplicate
# Row 12770 is a duplicate
# Row 12771 is a duplicate
# Row 12781 is a duplicate
# Row 12782 is a duplicate
# Row 12787 is a duplicate
# Row 12792 is a duplicate
# Row 12793 is a duplicate
# Row 12800 is a duplicate
# Row 12800 is a duplicate
# Row 12805 is a duplicate
# Row 12805 is a duplicate
# Row 12806 is a duplicate
# Row 12807 is a duplicate
# Row 12814 is a duplicate
# Row 12903 is a duplicate
# Row 12906 is a duplicate
# Row 12921 is a duplicate
# Row 12922 is a duplicate
# Row 12924 is a duplicate
# Row 12930 is a duplicate
# Row 12939 is a duplicate
# Row 12939 is a duplicate
# Row 12956 is a duplicate
# Row 12982 is a duplicate
# Row 12988 is a duplicate
# Row 12995 is a duplicate
# Row 13001 is a duplicate
# Row 13014 is a duplicate
# Row 13025 is a duplicate
# Row 13026 is a duplicate
# Row 13032 is a duplicate
# Row 13040 is a duplicate
# Row 13040 is a duplicate
# Row 13051 is a duplicate
# Row 13054 is a duplicate
# Row 13067 is a duplicate
# Row 13070 is a duplicate
# Row 13115 is a duplicate
# Row 13116 is a duplicate
# Row 13122 is a duplicate
# Row 13128 is a duplicate
# Row 13144 is a duplicate
# Row 13178 is a duplicate
# Row 13184 is a duplicate
# Row 13186 is a duplicate
# Row 13198 is a duplicate
# Row 13207 is a duplicate
# Row 13208 is a duplicate
# Row 13223 is a duplicate
# Row 13228 is a duplicate
# Row 13228 is a duplicate
# Row 13229 is a duplicate
# Row 13230 is a duplicate
# Row 13231 is a duplicate
# Row 13232 is a duplicate
# Row 13233 is a duplicate
# Row 13247 is a duplicate
# Row 13271 is a duplicate
# Row 13278 is a duplicate
# Row 13294 is a duplicate
# Row 13306 is a duplicate
# Row 13320 is a duplicate
# Row 13327 is a duplicate
# Row 13334 is a duplicate
# Row 13342 is a duplicate
# Row 13373 is a duplicate
# Row 13374 is a duplicate
# Row 13375 is a duplicate
# Row 13422 is a duplicate
# Row 13423 is a duplicate
# Row 13431 is a duplicate
# Row 13502 is a duplicate
# Row 13512 is a duplicate
# Row 13518 is a duplicate
# Row 13524 is a duplicate
# Row 13528 is a duplicate
# Row 13529 is a duplicate
# Row 13531 is a duplicate
# Row 13531 is a duplicate
# Row 13532 is a duplicate
# Row 13535 is a duplicate
# Row 13538 is a duplicate
# Row 13541 is a duplicate
# Row 13548 is a duplicate
# Row 13552 is a duplicate
# Row 13554 is a duplicate
# Row 13555 is a duplicate
# Row 13560 is a duplicate
# Row 13567 is a duplicate
# Row 13568 is a duplicate
# Row 13569 is a duplicate
# Row 13585 is a duplicate
# Row 13608 is a duplicate
# Row 13623 is a duplicate
# Row 13636 is a duplicate
# Row 13638 is a duplicate
# Row 13657 is a duplicate
# Row 13661 is a duplicate
# Row 13671 is a duplicate
# Row 13687 is a duplicate
# Row 13689 is a duplicate
# Row 13713 is a duplicate
# Row 13719 is a duplicate
# Row 13724 is a duplicate
# Row 13732 is a duplicate
# Row 13747 is a duplicate
# Row 13762 is a duplicate
# Row 13762 is a duplicate
# Row 13772 is a duplicate
# Row 13774 is a duplicate
# Row 13786 is a duplicate
# Row 13800 is a duplicate
# Row 13802 is a duplicate
# Row 13806 is a duplicate
# Row 13815 is a duplicate
# Row 13827 is a duplicate
# Row 13852 is a duplicate
# Row 13852 is a duplicate
# Row 13853 is a duplicate
# Row 13871 is a duplicate
# Row 13874 is a duplicate
# Row 13958 is a duplicate
# Row 13964 is a duplicate
# Row 13974 is a duplicate
# Row 13979 is a duplicate
# Row 13986 is a duplicate
# Row 13986 is a duplicate
# Row 13998 is a duplicate
# Row 13998 is a duplicate
# Row 14004 is a duplicate
# Row 14016 is a duplicate
# Row 14021 is a duplicate
# Row 14024 is a duplicate
# Row 14030 is a duplicate
# Row 14030 is a duplicate
# Row 14030 is a duplicate
# Row 14034 is a duplicate
# Row 14043 is a duplicate
# Row 14054 is a duplicate
# Row 14089 is a duplicate
# Row 14090 is a duplicate
# Row 14095 is a duplicate
# Row 14106 is a duplicate
# Row 14124 is a duplicate
# Row 14196 is a duplicate
# Row 14203 is a duplicate
# Row 14214 is a duplicate
# Row 14220 is a duplicate
# Row 14224 is a duplicate
# Row 14226 is a duplicate
# Row 14231 is a duplicate
# Row 14242 is a duplicate
# Row 14249 is a duplicate
# Row 14258 is a duplicate
# Row 14269 is a duplicate
# Row 14271 is a duplicate
# Row 14279 is a duplicate
# Row 14284 is a duplicate
# Row 14285 is a duplicate
# Row 14289 is a duplicate
# Row 14289 is a duplicate
# Row 14309 is a duplicate
# Row 14315 is a duplicate
# Row 14333 is a duplicate
# Row 14334 is a duplicate
# Row 14347 is a duplicate
# Row 14352 is a duplicate
# Row 14355 is a duplicate
# Row 14367 is a duplicate
# Row 14372 is a duplicate
# Row 14385 is a duplicate
# Row 14388 is a duplicate
# Row 14392 is a duplicate
# Row 14396 is a duplicate
# Row 14401 is a duplicate
# Row 14415 is a duplicate
# Row 14443 is a duplicate
# Row 14445 is a duplicate
# Row 14447 is a duplicate
# Row 14454 is a duplicate
# Row 14470 is a duplicate
# Row 14483 is a duplicate
# Row 14489 is a duplicate
# Row 14494 is a duplicate
# Row 14511 is a duplicate
# Row 14524 is a duplicate
# Row 14539 is a duplicate
# Row 14557 is a duplicate
# Row 14606 is a duplicate
# Row 14619 is a duplicate
# Row 14621 is a duplicate
# Row 14623 is a duplicate
# Row 14668 is a duplicate
# Row 14685 is a duplicate
# Row 14696 is a duplicate
# Row 14712 is a duplicate
# Row 14733 is a duplicate
# Row 14735 is a duplicate
# Row 14766 is a duplicate
# Row 14813 is a duplicate
# Row 14815 is a duplicate
# Row 14847 is a duplicate
# Row 14859 is a duplicate
# Row 14864 is a duplicate
# Row 14865 is a duplicate
# Row 14892 is a duplicate
# Row 14905 is a duplicate
# Row 14911 is a duplicate
# Row 14929 is a duplicate
# Row 14930 is a duplicate
# Row 14945 is a duplicate
# Row 14949 is a duplicate
# Row 14949 is a duplicate
# Row 14952 is a duplicate
# Row 14953 is a duplicate
# Row 14970 is a duplicate
# Row 14995 is a duplicate
# Row 15008 is a duplicate
# Row 15023 is a duplicate
# Row 15025 is a duplicate
# Row 15034 is a duplicate
# Row 15039 is a duplicate
# Row 15041 is a duplicate
# Row 15061 is a duplicate
# Row 15064 is a duplicate
# Row 15065 is a duplicate
# Row 15066 is a duplicate
# Row 15066 is a duplicate
# Row 15073 is a duplicate
# Row 15074 is a duplicate
# Row 15075 is a duplicate
# Row 15076 is a duplicate
# Row 15077 is a duplicate
# Row 15082 is a duplicate
# Row 15083 is a duplicate
# Row 15084 is a duplicate
# Row 15104 is a duplicate
# Row 15124 is a duplicate
# Row 15152 is a duplicate
# Row 15178 is a duplicate
# Row 15179 is a duplicate
# Row 15180 is a duplicate
# Row 15195 is a duplicate
# Row 15199 is a duplicate
# Row 15199 is a duplicate
# Row 15204 is a duplicate
# Row 15243 is a duplicate
# Row 15285 is a duplicate
# Row 15286 is a duplicate
# Row 15293 is a duplicate
# Row 15329 is a duplicate
# Row 15358 is a duplicate
# Row 15375 is a duplicate
# Row 15376 is a duplicate
# Row 15389 is a duplicate
# Row 15404 is a duplicate
# Row 15408 is a duplicate
# Row 15409 is a duplicate
# Row 15411 is a duplicate
# Row 15412 is a duplicate
# Row 15413 is a duplicate
# Row 15432 is a duplicate
# Row 15443 is a duplicate
# Row 15444 is a duplicate
# Row 15491 is a duplicate
# Row 15496 is a duplicate
# Row 15497 is a duplicate
# Row 15511 is a duplicate
# Row 15512 is a duplicate
# Row 15516 is a duplicate
# Row 15519 is a duplicate
# Row 15521 is a duplicate
# Row 15527 is a duplicate
# Row 15531 is a duplicate
# Row 15534 is a duplicate
# Row 15541 is a duplicate
# Row 15549 is a duplicate
# Row 15552 is a duplicate
# Row 15553 is a duplicate
# Row 15554 is a duplicate
# Row 15559 is a duplicate
# Row 15559 is a duplicate
# Row 15581 is a duplicate
# Row 15603 is a duplicate
# Row 15609 is a duplicate
# Row 15609 is a duplicate
# Row 15623 is a duplicate
# Row 15631 is a duplicate
# Row 15632 is a duplicate
# Row 15639 is a duplicate
# Row 15643 is a duplicate
# Row 15652 is a duplicate
# Row 15658 is a duplicate
# Row 15689 is a duplicate
# Row 15708 is a duplicate
# Row 15729 is a duplicate
# Row 15847 is a duplicate
# Row 15860 is a duplicate
# Row 15883 is a duplicate
# Row 15883 is a duplicate
# Row 15883 is a duplicate
# Row 15885 is a duplicate
# Row 15904 is a duplicate
# Row 15914 is a duplicate
# Row 15932 is a duplicate
# Row 15960 is a duplicate
# Row 16001 is a duplicate
# Row 16037 is a duplicate
# Row 16041 is a duplicate
# Row 16051 is a duplicate
# Row 16096 is a duplicate
# Row 16170 is a duplicate
# Row 16171 is a duplicate
# Row 16215 is a duplicate
# Row 16217 is a duplicate
# Row 16217 is a duplicate
# Row 16218 is a duplicate
# Row 16224 is a duplicate
# Row 16224 is a duplicate
# Row 16224 is a duplicate
# Row 16225 is a duplicate
# Row 16227 is a duplicate
# Row 16230 is a duplicate
# Row 16231 is a duplicate
# Row 16231 is a duplicate
# Row 16233 is a duplicate
# Row 16241 is a duplicate
# Row 16243 is a duplicate
# Row 16245 is a duplicate
# Row 16247 is a duplicate
# Row 16252 is a duplicate
# Row 16252 is a duplicate
# Row 16258 is a duplicate
# Row 16259 is a duplicate
# Row 16261 is a duplicate
# Row 16283 is a duplicate
# Row 16304 is a duplicate
# Row 16312 is a duplicate
# Row 16349 is a duplicate
# Row 16353 is a duplicate
# Row 16368 is a duplicate
# Row 16378 is a duplicate
# Row 16382 is a duplicate
# Row 16385 is a duplicate
# Row 16387 is a duplicate
# Row 16388 is a duplicate
# Row 16412 is a duplicate
# Row 16413 is a duplicate
# Row 16429 is a duplicate
# Row 16458 is a duplicate
# Row 16462 is a duplicate
# Row 16462 is a duplicate
# Row 16462 is a duplicate
# Row 16485 is a duplicate
# Row 16499 is a duplicate
# Row 16499 is a duplicate
# Row 16501 is a duplicate
# Row 16513 is a duplicate
# Row 16530 is a duplicate
# Row 16555 is a duplicate
# Row 16573 is a duplicate
# Row 16583 is a duplicate
# Row 16585 is a duplicate
# Row 16590 is a duplicate
# Row 16592 is a duplicate
# Row 16607 is a duplicate
# Row 16624 is a duplicate
# Row 16626 is a duplicate
# Row 16654 is a duplicate
# Row 16657 is a duplicate
# Row 16665 is a duplicate
# Row 16667 is a duplicate
# Row 16670 is a duplicate
# Row 16683 is a duplicate
# Row 16686 is a duplicate
# Row 16687 is a duplicate
# Row 16687 is a duplicate
# Row 16691 is a duplicate
# Row 16694 is a duplicate
# Row 16708 is a duplicate
# Row 16719 is a duplicate
# Row 16722 is a duplicate
# Row 16725 is a duplicate
# Row 16730 is a duplicate
# Row 16733 is a duplicate
# Row 16767 is a duplicate
# Row 16778 is a duplicate
# Row 16791 is a duplicate
# Row 16792 is a duplicate
# Row 16802 is a duplicate
# Row 16804 is a duplicate
# Row 16805 is a duplicate
# Row 16827 is a duplicate
# Row 16831 is a duplicate
# Row 16878 is a duplicate
# Row 16894 is a duplicate
# Row 16911 is a duplicate
# Row 16911 is a duplicate
# Row 16917 is a duplicate
# Row 16918 is a duplicate
# Row 16936 is a duplicate
# Row 16938 is a duplicate
# Row 16946 is a duplicate
# Row 16968 is a duplicate
# Row 16969 is a duplicate
# Row 16978 is a duplicate
# Row 16985 is a duplicate
# Row 16999 is a duplicate
# Row 17019 is a duplicate
# Row 17028 is a duplicate
# Row 17034 is a duplicate
# Row 17049 is a duplicate
# Row 17058 is a duplicate
# Row 17061 is a duplicate
# Row 17064 is a duplicate
# Row 17075 is a duplicate
# Row 17082 is a duplicate
# Row 17100 is a duplicate
# Row 17140 is a duplicate
# Row 17195 is a duplicate
# Row 17199 is a duplicate
# Row 17203 is a duplicate
# Row 17206 is a duplicate
# Row 17214 is a duplicate
# Row 17229 is a duplicate
# Row 17231 is a duplicate
# Row 17260 is a duplicate
# Row 17277 is a duplicate
# Row 17303 is a duplicate
# Row 17317 is a duplicate
# Row 17363 is a duplicate
# Row 17417 is a duplicate
# Row 17424 is a duplicate
# Row 17436 is a duplicate
# Row 17437 is a duplicate
# Row 17444 is a duplicate
# Row 17461 is a duplicate
# Row 17463 is a duplicate
# Row 17470 is a duplicate
# Row 17473 is a duplicate
# Row 17476 is a duplicate
# Row 17478 is a duplicate
# Row 17479 is a duplicate
# Row 17480 is a duplicate
# Row 17523 is a duplicate
# Row 17528 is a duplicate
# Row 17529 is a duplicate
# Row 17541 is a duplicate
# Row 17541 is a duplicate
# Row 17562 is a duplicate
# Row 17572 is a duplicate
# Row 17585 is a duplicate
# Row 17637 is a duplicate
# Row 17648 is a duplicate
# Row 17652 is a duplicate
# Row 17657 is a duplicate
# Row 17666 is a duplicate
# Row 17667 is a duplicate
# Row 17670 is a duplicate
# Row 17670 is a duplicate
# Row 17671 is a duplicate
# Row 17676 is a duplicate
# Row 17682 is a duplicate
# Row 17682 is a duplicate
# Row 17683 is a duplicate
# Row 17688 is a duplicate
# Row 17698 is a duplicate
# Row 17699 is a duplicate
# Row 17699 is a duplicate
# Row 17704 is a duplicate
# Row 17761 is a duplicate
# Row 17761 is a duplicate
# Row 17762 is a duplicate
# Row 17776 is a duplicate
# Row 17777 is a duplicate
# Row 17782 is a duplicate
# Row 17789 is a duplicate
# Row 17796 is a duplicate
# Row 17796 is a duplicate
# Row 17802 is a duplicate
# Row 17810 is a duplicate
# Row 17810 is a duplicate
# Row 17820 is a duplicate
# Row 17823 is a duplicate
# Row 17824 is a duplicate
# Row 17825 is a duplicate
# Row 17827 is a duplicate
# Row 17842 is a duplicate
# Row 17844 is a duplicate
# Row 17845 is a duplicate
# Row 17848 is a duplicate
# Row 17877 is a duplicate
# Row 17882 is a duplicate
# Row 17888 is a duplicate
# Row 17899 is a duplicate
# Row 17900 is a duplicate
# Row 17909 is a duplicate
# Row 17912 is a duplicate
# Row 17913 is a duplicate
# Row 17918 is a duplicate
# Row 17924 is a duplicate
# Row 17941 is a duplicate
# Row 17953 is a duplicate
# Row 17964 is a duplicate
# Row 17967 is a duplicate
# Row 17998 is a duplicate
# Row 18005 is a duplicate
# Row 18021 is a duplicate
# Row 18103 is a duplicate
# Row 18135 is a duplicate
# Row 18151 is a duplicate
# Row 18175 is a duplicate
# Row 18178 is a duplicate
# Row 18210 is a duplicate
# Row 18218 is a duplicate
# Row 18220 is a duplicate
# Row 18232 is a duplicate
# Row 18239 is a duplicate
# Row 18240 is a duplicate
# Row 18241 is a duplicate
# Row 18268 is a duplicate
# Row 18285 is a duplicate
# Row 18350 is a duplicate
# Row 18354 is a duplicate
# Row 18361 is a duplicate
# Row 18361 is a duplicate
# Row 18364 is a duplicate
# Row 18377 is a duplicate
# Row 18381 is a duplicate
# Row 18407 is a duplicate
# Row 18437 is a duplicate
# Row 18459 is a duplicate
# Row 18463 is a duplicate
# Row 18477 is a duplicate
# Row 18479 is a duplicate
# Row 18498 is a duplicate
# Row 18509 is a duplicate
# Row 18522 is a duplicate
# Row 18526 is a duplicate
# Row 18532 is a duplicate
# Row 18538 is a duplicate
# Row 18568 is a duplicate
# Row 18582 is a duplicate
# Row 18589 is a duplicate
# Row 18598 is a duplicate
# Row 18619 is a duplicate
# Row 18619 is a duplicate
# Row 18633 is a duplicate
# Row 18634 is a duplicate
# Row 18645 is a duplicate
# Row 18646 is a duplicate
# Row 18656 is a duplicate
# Row 18676 is a duplicate
# Row 18683 is a duplicate
# Row 18684 is a duplicate
# Row 18685 is a duplicate
# Row 18690 is a duplicate
# Row 18708 is a duplicate
# Row 18710 is a duplicate
# Row 18778 is a duplicate
# Row 18779 is a duplicate
# Row 18780 is a duplicate
# Row 18790 is a duplicate
# Row 18836 is a duplicate
# Row 18840 is a duplicate
# Row 18842 is a duplicate
# Row 18846 is a duplicate
# Row 18891 is a duplicate
# Row 18924 is a duplicate
# Row 18928 is a duplicate
# Row 18929 is a duplicate
# Row 18930 is a duplicate
# Row 18936 is a duplicate
# Row 18955 is a duplicate
# Row 18958 is a duplicate
# Row 18966 is a duplicate
# Row 18972 is a duplicate
# Row 18974 is a duplicate
# Row 19004 is a duplicate
# Row 19004 is a duplicate
# Row 19028 is a duplicate
# Row 19080 is a duplicate
# Row 19089 is a duplicate
# Row 19104 is a duplicate
# Row 19114 is a duplicate
# Row 19127 is a duplicate
# Row 19157 is a duplicate
# Row 19163 is a duplicate
# Row 19165 is a duplicate
# Row 19166 is a duplicate
# Row 19174 is a duplicate
# Row 19180 is a duplicate
# Row 19184 is a duplicate
# Row 19186 is a duplicate
# Row 19189 is a duplicate
# Row 19190 is a duplicate
# Row 19202 is a duplicate
# Row 19205 is a duplicate
# Row 19207 is a duplicate
# Row 19212 is a duplicate
# Row 19212 is a duplicate
# Row 19224 is a duplicate
# Row 19226 is a duplicate
# Row 19236 is a duplicate
# Row 19237 is a duplicate
# Row 19238 is a duplicate
# Row 19257 is a duplicate
# Row 19285 is a duplicate
# Row 19289 is a duplicate
# Row 19291 is a duplicate
# Row 19317 is a duplicate
# Row 19319 is a duplicate
# Row 19332 is a duplicate
# Row 19338 is a duplicate
# Row 19371 is a duplicate
# Row 19375 is a duplicate
# Row 19391 is a duplicate
# Row 19396 is a duplicate
# Row 19397 is a duplicate
# Row 19401 is a duplicate
# Row 19406 is a duplicate
# Row 19406 is a duplicate
# Row 19421 is a duplicate
# Row 19426 is a duplicate
# Row 19432 is a duplicate
# Row 19433 is a duplicate
# Row 19434 is a duplicate
# Row 19446 is a duplicate
# Row 19464 is a duplicate
# Row 19468 is a duplicate
# Row 19473 is a duplicate
# Row 19477 is a duplicate
# Row 19478 is a duplicate
# Row 19484 is a duplicate
# Row 19488 is a duplicate
# Row 19529 is a duplicate
# Row 19537 is a duplicate
# Row 19581 is a duplicate
# Row 19584 is a duplicate
# Row 19585 is a duplicate
# Row 19610 is a duplicate
# Row 19635 is a duplicate
# Row 19637 is a duplicate
# Row 19637 is a duplicate
# Row 19654 is a duplicate
# Row 19655 is a duplicate
# Row 19676 is a duplicate
# Row 19682 is a duplicate
# Row 19693 is a duplicate
# Row 19714 is a duplicate
# Row 19714 is a duplicate
# Row 19727 is a duplicate
# Row 19743 is a duplicate
# Row 19754 is a duplicate
# Row 19757 is a duplicate
# Row 19758 is a duplicate
# Row 19770 is a duplicate
# Row 19776 is a duplicate
# Row 19815 is a duplicate
# Row 19832 is a duplicate
# Row 19940 is a duplicate
# Row 19943 is a duplicate
# Row 19952 is a duplicate
# Row 19954 is a duplicate
# Row 19963 is a duplicate
# Row 19968 is a duplicate
# Row 19985 is a duplicate
# Row 20007 is a duplicate
# Row 20020 is a duplicate
# Row 20021 is a duplicate
# Row 20022 is a duplicate
# Row 20023 is a duplicate
# Row 20023 is a duplicate
# Row 20026 is a duplicate
# Row 20027 is a duplicate
# Row 20056 is a duplicate
# Row 20062 is a duplicate
# Row 20092 is a duplicate
# Row 20107 is a duplicate
# Row 20130 is a duplicate
# Row 20135 is a duplicate
# Row 20138 is a duplicate
# Row 20143 is a duplicate
# Row 20146 is a duplicate
# Row 20162 is a duplicate
# Row 20170 is a duplicate
# Row 20181 is a duplicate
# Row 20193 is a duplicate
# Row 20197 is a duplicate
# Row 20200 is a duplicate
# Row 20203 is a duplicate
# Row 20217 is a duplicate
# Row 20232 is a duplicate
# Row 20244 is a duplicate
# Row 20249 is a duplicate
# Row 20259 is a duplicate
# Row 20324 is a duplicate
# Row 20331 is a duplicate
# Row 20333 is a duplicate
# Row 20334 is a duplicate
# Row 20335 is a duplicate
# Row 20384 is a duplicate
# Row 20394 is a duplicate
# Row 20403 is a duplicate
# Row 20412 is a duplicate
# Row 20443 is a duplicate
# Row 20444 is a duplicate
# Row 20445 is a duplicate
# Row 20456 is a duplicate
# Row 20465 is a duplicate
# Row 20489 is a duplicate
# Row 20507 is a duplicate
# Row 20515 is a duplicate
# Row 20526 is a duplicate
# Row 20531 is a duplicate
# Row 20550 is a duplicate
# Row 20551 is a duplicate
# Row 20559 is a duplicate
# Row 20561 is a duplicate
# Row 20567 is a duplicate
# Row 20572 is a duplicate
# Row 20572 is a duplicate
# Row 20585 is a duplicate
# Row 20603 is a duplicate
# Row 20616 is a duplicate
# Row 20620 is a duplicate
# Row 20657 is a duplicate
# Row 20664 is a duplicate
# Row 20668 is a duplicate
# Row 20669 is a duplicate
# Row 20681 is a duplicate
# Row 20777 is a duplicate
# Row 20790 is a duplicate
# Row 20792 is a duplicate
# Row 20800 is a duplicate
# Row 20801 is a duplicate
# Row 20809 is a duplicate
# Row 20836 is a duplicate
# Row 20836 is a duplicate
# Row 20843 is a duplicate
# Row 20872 is a duplicate
# Row 20877 is a duplicate
# Row 20882 is a duplicate
# Row 20906 is a duplicate
# Row 20907 is a duplicate
# Row 20914 is a duplicate
# Row 20930 is a duplicate
# Row 20945 is a duplicate
# Row 20948 is a duplicate
# Row 20953 is a duplicate
# Row 20967 is a duplicate
# Row 20967 is a duplicate
# Row 20971 is a duplicate
# Row 20974 is a duplicate
# Row 20974 is a duplicate
# Row 20986 is a duplicate
# Row 20993 is a duplicate
# Row 20999 is a duplicate
# Row 21002 is a duplicate
# Row 21014 is a duplicate
# Row 21066 is a duplicate
# Row 21074 is a duplicate
# Row 21078 is a duplicate
# Row 21091 is a duplicate
# Row 21100 is a duplicate
# Row 21101 is a duplicate
# Row 21106 is a duplicate
# Row 21124 is a duplicate
# Row 21125 is a duplicate
# Row 21130 is a duplicate
# Row 21140 is a duplicate
# Row 21152 is a duplicate
# Row 21158 is a duplicate
# Row 21189 is a duplicate
# Row 21190 is a duplicate
# Row 21219 is a duplicate
# Row 21245 is a duplicate
# Row 21247 is a duplicate
# Row 21256 is a duplicate
# Row 21269 is a duplicate
# Row 21294 is a duplicate
# Row 21308 is a duplicate
# Row 21312 is a duplicate
# Row 21317 is a duplicate
# Row 21318 is a duplicate
# Row 21322 is a duplicate
# Row 21328 is a duplicate
# Row 21347 is a duplicate
# Row 21350 is a duplicate
# Row 21351 is a duplicate
# Row 21360 is a duplicate
# Row 21369 is a duplicate
# Row 21374 is a duplicate
# Row 21379 is a duplicate
# Row 21395 is a duplicate
# Row 21395 is a duplicate
# Row 21395 is a duplicate
# Row 21409 is a duplicate
# Row 21413 is a duplicate
# Row 21430 is a duplicate
# Row 21439 is a duplicate
# Row 21460 is a duplicate
# Row 21469 is a duplicate
# Row 21490 is a duplicate
# Row 21494 is a duplicate
# Row 21495 is a duplicate
# Row 21510 is a duplicate
# Row 21513 is a duplicate
# Row 21544 is a duplicate
# Row 21576 is a duplicate
# Row 21586 is a duplicate
# Row 21586 is a duplicate
# Row 21599 is a duplicate
# ...
# Row 27886 is a duplicate
# Row 27887 is a duplicate
# Row 27895 is a duplicate
# Row 27898 is a duplicate
# Row 27898 is a duplicate
# Row 27908 is a duplicate
# Row 27909 is a duplicate
# Row 27912 is a duplicate
# Row 27913 is a duplicate
# Row 27930 is a duplicate
# Row 27950 is a duplicate
# Row 27956 is a duplicate
# Row 27962 is a duplicate
# Row 27964 is a duplicate
# Row 28010 is a duplicate
# Row 28012 is a duplicate
# Row 28012 is a duplicate
# Row 28016 is a duplicate
# Row 28016 is a duplicate
# Row 28022 is a duplicate
# Row 28029 is a duplicate
# Row 28031 is a duplicate
# Row 28032 is a duplicate
# Row 28035 is a duplicate
# Row 28038 is a duplicate
# Row 28040 is a duplicate
# Row 28081 is a duplicate
# Row 28089 is a duplicate
# Row 28093 is a duplicate
# Row 28094 is a duplicate
# Row 28100 is a duplicate
# Row 28112 is a duplicate
# Row 28121 is a duplicate
# Row 28137 is a duplicate
# Row 28167 is a duplicate
# Row 28239 is a duplicate
# Row 28282 is a duplicate
# Row 28294 is a duplicate
# Row 28302 is a duplicate
# Row 28305 is a duplicate
# Row 28313 is a duplicate
# Row 28340 is a duplicate
# Row 28358 is a duplicate
# Row 28359 is a duplicate
# Row 28369 is a duplicate
# Row 28391 is a duplicate
# Row 28472 is a duplicate
# Row 28506 is a duplicate
# Row 28517 is a duplicate
# Row 28518 is a duplicate
# Row 28546 is a duplicate
# Row 28559 is a duplicate
# Row 28564 is a duplicate
# Row 28570 is a duplicate
# Row 28573 is a duplicate
# Row 28573 is a duplicate
# Row 28574 is a duplicate
# Row 28574 is a duplicate
# Row 28577 is a duplicate
# Row 28580 is a duplicate
# Row 28608 is a duplicate
# Row 28612 is a duplicate
# Row 28636 is a duplicate
# Row 28663 is a duplicate
# Row 28667 is a duplicate
# Row 28693 is a duplicate
# Row 28721 is a duplicate
# Row 28723 is a duplicate
# Row 28753 is a duplicate
# Row 28778 is a duplicate
# Row 28789 is a duplicate
# Row 28790 is a duplicate
# Row 28805 is a duplicate
# Row 28814 is a duplicate
# Row 28822 is a duplicate
# Row 28834 is a duplicate
# Row 28855 is a duplicate
# Row 28903 is a duplicate
# Row 28936 is a duplicate
# Row 28944 is a duplicate
# Row 28944 is a duplicate
# Row 28966 is a duplicate
# Row 28973 is a duplicate
# Row 28979 is a duplicate
# Row 28987 is a duplicate
# Row 28987 is a duplicate
# Row 28990 is a duplicate
# Row 28996 is a duplicate
# Row 29001 is a duplicate
# Row 29002 is a duplicate
# Row 29007 is a duplicate
# Row 29007 is a duplicate
# Row 29011 is a duplicate
# Row 29012 is a duplicate
# Row 29021 is a duplicate
# Row 29025 is a duplicate
# Row 29032 is a duplicate
# Row 29045 is a duplicate
# Row 29052 is a duplicate
# Row 29059 is a duplicate
# Row 29075 is a duplicate
# Row 29083 is a duplicate
# Row 29093 is a duplicate
# Row 29127 is a duplicate
# Row 29129 is a duplicate
# Row 29132 is a duplicate
# Row 29147 is a duplicate
# Row 29160 is a duplicate
# Row 29162 is a duplicate
# Row 29173 is a duplicate
# Row 29206 is a duplicate
# Row 29231 is a duplicate
# Row 29243 is a duplicate
# Row 29276 is a duplicate
# Row 29277 is a duplicate
# Row 29277 is a duplicate
# Row 29281 is a duplicate
# Row 29296 is a duplicate
# Row 29314 is a duplicate
# Row 29317 is a duplicate
# Row 29326 is a duplicate
# Row 29328 is a duplicate
# Row 29333 is a duplicate
# Row 29340 is a duplicate
# Row 29344 is a duplicate
# Row 29353 is a duplicate
# Row 29354 is a duplicate
# Row 29357 is a duplicate
# Row 29365 is a duplicate
# Row 29372 is a duplicate
# Row 29374 is a duplicate
# Row 29374 is a duplicate
# Row 29381 is a duplicate
# Row 29382 is a duplicate
# Row 29384 is a duplicate
# Row 29385 is a duplicate
# Row 29387 is a duplicate
# Row 29430 is a duplicate
# Row 29435 is a duplicate
# Row 29446 is a duplicate
# Row 29462 is a duplicate
# Row 29499 is a duplicate
# Row 29506 is a duplicate
# Row 29542 is a duplicate
# Row 29547 is a duplicate
# Row 29549 is a duplicate
# Row 29549 is a duplicate
# Row 29567 is a duplicate
# Row 29584 is a duplicate
# Row 29590 is a duplicate
# Row 29596 is a duplicate
# Row 29597 is a duplicate
# Row 29598 is a duplicate
# Row 29634 is a duplicate
# Row 29636 is a duplicate
# Row 29641 is a duplicate
# Row 29651 is a duplicate
# Row 29652 is a duplicate
# Row 29653 is a duplicate
# Row 29659 is a duplicate
# Row 29664 is a duplicate
# Row 29668 is a duplicate
# Row 29670 is a duplicate
# Row 29673 is a duplicate
# Row 29678 is a duplicate
# Row 29689 is a duplicate
# Row 29694 is a duplicate
# Row 29728 is a duplicate
# Row 29736 is a duplicate
# Row 29746 is a duplicate
# Row 29762 is a duplicate
# Row 29770 is a duplicate
# Row 29775 is a duplicate
# Row 29784 is a duplicate
# Row 29789 is a duplicate
# Row 29796 is a duplicate
# Row 29797 is a duplicate
# Row 29807 is a duplicate
# Row 29839 is a duplicate
# Row 29870 is a duplicate
# Row 29874 is a duplicate
# Row 29878 is a duplicate
# Row 29896 is a duplicate
# Row 29905 is a duplicate
# Row 29913 is a duplicate
# Row 29946 is a duplicate
# Row 29949 is a duplicate
# Row 29949 is a duplicate
# Row 29950 is a duplicate
# Row 29967 is a duplicate
# Row 29972 is a duplicate
# Row 29980 is a duplicate
# Row 29986 is a duplicate
# Row 29994 is a duplicate
# Row 29999 is a duplicate
# Row 30004 is a duplicate
# Row 30005 is a duplicate
# Row 30005 is a duplicate
# Row 30010 is a duplicate
# Row 30026 is a duplicate
# Row 30031 is a duplicate
# Row 30055 is a duplicate
# Row 30070 is a duplicate
# Row 30074 is a duplicate
# Row 30076 is a duplicate
# Row 30087 is a duplicate
# Row 30104 is a duplicate
# Row 30109 is a duplicate
# Row 30116 is a duplicate
# Row 30125 is a duplicate
# Row 30125 is a duplicate
# Row 30134 is a duplicate
# Row 30143 is a duplicate
# Row 30153 is a duplicate
# Row 30156 is a duplicate
# Row 30158 is a duplicate
# Row 30168 is a duplicate
# Row 30179 is a duplicate
# Row 30242 is a duplicate
# Row 30271 is a duplicate
# Row 30275 is a duplicate
# Row 30276 is a duplicate
# Row 30353 is a duplicate
# Row 30353 is a duplicate
# Row 30371 is a duplicate
# Row 30385 is a duplicate
# Row 30387 is a duplicate
# Row 30387 is a duplicate
# Row 30389 is a duplicate
# Row 30396 is a duplicate
# Row 30419 is a duplicate
# Row 30447 is a duplicate
# Row 30481 is a duplicate
# Row 30483 is a duplicate
# Row 30484 is a duplicate
# Row 30486 is a duplicate
# Row 30540 is a duplicate
# Row 30543 is a duplicate
# Row 30550 is a duplicate
# Row 30551 is a duplicate
# Row 30578 is a duplicate
# Row 30586 is a duplicate
# Row 30591 is a duplicate
# Row 30593 is a duplicate
# Row 30594 is a duplicate
# Row 30608 is a duplicate
# Row 30610 is a duplicate
# Row 30624 is a duplicate
# Row 30625 is a duplicate
# Row 30627 is a duplicate
# Row 30676 is a duplicate
# Row 30707 is a duplicate
# Row 30709 is a duplicate
# Row 30720 is a duplicate
# Row 30725 is a duplicate
# Row 30729 is a duplicate
# Row 30738 is a duplicate
# Row 30738 is a duplicate
# Row 30739 is a duplicate
# Row 30742 is a duplicate
# Row 30743 is a duplicate
# Row 30751 is a duplicate
# Row 30773 is a duplicate
# Row 30779 is a duplicate
# Row 30790 is a duplicate
# Row 30807 is a duplicate
# Row 30811 is a duplicate
# Row 30828 is a duplicate
# Row 30830 is a duplicate
# Row 30840 is a duplicate
# Row 30842 is a duplicate
# Row 30843 is a duplicate
# Row 30876 is a duplicate
# Row 30901 is a duplicate
# Row 30902 is a duplicate
# Row 30908 is a duplicate
# Row 30919 is a duplicate
# Row 30947 is a duplicate
# Row 30954 is a duplicate
# Row 30980 is a duplicate
# Row 30996 is a duplicate
# Row 31016 is a duplicate
# Row 31024 is a duplicate
# Row 31063 is a duplicate
# Row 31076 is a duplicate
# Row 31089 is a duplicate
# Row 31090 is a duplicate
# Row 31112 is a duplicate
# Row 31118 is a duplicate
# Row 31120 is a duplicate
# Row 31122 is a duplicate
# Row 31123 is a duplicate
# Row 31129 is a duplicate
# Row 31142 is a duplicate
# Row 31153 is a duplicate
# Row 31182 is a duplicate
# Row 31186 is a duplicate
# Row 31189 is a duplicate
# Row 31206 is a duplicate
# Row 31215 is a duplicate
# Row 31221 is a duplicate
# Row 31222 is a duplicate
# Row 31240 is a duplicate
# Row 31241 is a duplicate
# Row 31251 is a duplicate
# Row 31252 is a duplicate
# Row 31255 is a duplicate
# Row 31269 is a duplicate
# Row 31278 is a duplicate
# Row 31285 is a duplicate
# Row 31326 is a duplicate
# Row 31365 is a duplicate
# Row 31376 is a duplicate
# Row 31377 is a duplicate
# Row 31418 is a duplicate
# Row 31420 is a duplicate
# Row 31437 is a duplicate
# Row 31443 is a duplicate
# Row 31456 is a duplicate
# Row 31458 is a duplicate
# Row 31467 is a duplicate
# Row 31469 is a duplicate
# Row 31471 is a duplicate
# Row 31471 is a duplicate
# Row 31473 is a duplicate
# Row 31476 is a duplicate
# Row 31490 is a duplicate
# Row 31491 is a duplicate
# Row 31516 is a duplicate
# Row 31530 is a duplicate
# Row 31539 is a duplicate
# Row 31549 is a duplicate
# Row 31558 is a duplicate
# Row 31595 is a duplicate
# Row 31612 is a duplicate
# Row 31630 is a duplicate
# Row 31639 is a duplicate
# Row 31644 is a duplicate
# Row 31656 is a duplicate
# Row 31664 is a duplicate
# Row 31715 is a duplicate
# Row 31750 is a duplicate
# Row 31757 is a duplicate
# Row 31801 is a duplicate
# Row 31815 is a duplicate
# Row 31816 is a duplicate
# Row 31840 is a duplicate
# Row 31844 is a duplicate
# Row 31844 is a duplicate
# Row 31856 is a duplicate
# Row 31863 is a duplicate
# Row 31874 is a duplicate
# Row 31876 is a duplicate
# Row 31880 is a duplicate
# Row 31881 is a duplicate
# Row 31904 is a duplicate
# Row 31905 is a duplicate
# Row 31915 is a duplicate
# Row 31915 is a duplicate
# Row 31918 is a duplicate
# Row 31922 is a duplicate
# Row 31930 is a duplicate
# Row 31991 is a duplicate
# Row 31993 is a duplicate
# Row 31995 is a duplicate
# Row 32006 is a duplicate
# Row 32019 is a duplicate
# Row 32020 is a duplicate
# Row 32022 is a duplicate
# Row 32032 is a duplicate
# Row 32033 is a duplicate
# Row 32040 is a duplicate
# Row 32073 is a duplicate
# Row 32079 is a duplicate
# Row 32096 is a duplicate
# Row 32140 is a duplicate
# Row 32146 is a duplicate
# Row 32153 is a duplicate
# Row 32153 is a duplicate
# Row 32224 is a duplicate
# Row 32259 is a duplicate
# Row 32298 is a duplicate
# Row 32324 is a duplicate
# Row 32330 is a duplicate
# Row 32330 is a duplicate
# Row 32339 is a duplicate
# Row 32339 is a duplicate
# Row 32340 is a duplicate
# Row 32344 is a duplicate
# Row 32359 is a duplicate
# Row 32364 is a duplicate
# Row 32373 is a duplicate
# Row 32403 is a duplicate
# Row 32407 is a duplicate
# Row 32408 is a duplicate
# Row 32409 is a duplicate
# Row 32412 is a duplicate
# Row 32416 is a duplicate
# Row 32416 is a duplicate
# Row 32421 is a duplicate
# Row 32435 is a duplicate
# Row 32442 is a duplicate
# Row 32457 is a duplicate
# Row 32460 is a duplicate
# Row 32472 is a duplicate
# Row 32475 is a duplicate
# Row 32490 is a duplicate
# Row 32493 is a duplicate
# Row 32499 is a duplicate
# Row 32538 is a duplicate
# Row 32539 is a duplicate
# Row 32583 is a duplicate
# Row 32621 is a duplicate
# Row 32625 is a duplicate
# Row 32632 is a duplicate
# Row 32653 is a duplicate
# Row 32674 is a duplicate
# Row 32675 is a duplicate
# Row 32677 is a duplicate
# Row 32686 is a duplicate
# Row 32687 is a duplicate
# Row 32745 is a duplicate
# Row 32747 is a duplicate
# Row 32754 is a duplicate
# Row 32758 is a duplicate
# Row 32828 is a duplicate
# Row 32855 is a duplicate
# Row 32886 is a duplicate
# Row 32891 is a duplicate
# Row 32924 is a duplicate
# Row 32963 is a duplicate
# Row 32970 is a duplicate
# Row 32979 is a duplicate
# Row 32981 is a duplicate
# Row 32983 is a duplicate
# Row 32984 is a duplicate
# Row 32986 is a duplicate
# Row 32993 is a duplicate
# Row 32994 is a duplicate
# Row 33022 is a duplicate
# Row 33022 is a duplicate
# Row 33027 is a duplicate
# Row 33028 is a duplicate
# Row 33029 is a duplicate
# Row 33030 is a duplicate
# Row 33036 is a duplicate
# Row 33043 is a duplicate
# Row 33044 is a duplicate
# Row 33048 is a duplicate
# Row 33057 is a duplicate
# Row 33073 is a duplicate
# Row 33083 is a duplicate
# Row 33085 is a duplicate
# Row 33105 is a duplicate
# Row 33106 is a duplicate
# Row 33107 is a duplicate
# Row 33136 is a duplicate
# Row 33155 is a duplicate
# Row 33172 is a duplicate
# Row 33177 is a duplicate
# Row 33181 is a duplicate
# Row 33191 is a duplicate
# Row 33201 is a duplicate
# Row 33203 is a duplicate
# Row 33209 is a duplicate
# Row 33210 is a duplicate
# Row 33210 is a duplicate
# Row 33228 is a duplicate
# Row 33233 is a duplicate
# Row 33241 is a duplicate
# Row 33244 is a duplicate
# Row 33244 is a duplicate
# Row 33288 is a duplicate
# Row 33290 is a duplicate
# Row 33295 is a duplicate
# Row 33321 is a duplicate
# Row 33326 is a duplicate
# Row 33328 is a duplicate
# Row 33329 is a duplicate
# Row 33338 is a duplicate
# Row 33353 is a duplicate
# Row 33357 is a duplicate
# Row 33377 is a duplicate
# Row 33390 is a duplicate
# Row 33393 is a duplicate
# Row 33401 is a duplicate
# Row 33406 is a duplicate
# Row 33407 is a duplicate
# Row 33412 is a duplicate
# Row 33420 is a duplicate
# Row 33424 is a duplicate
# Row 33426 is a duplicate
# Row 33427 is a duplicate
# Row 33427 is a duplicate
# Row 33428 is a duplicate
# Row 33431 is a duplicate
# Row 33448 is a duplicate
# Row 33477 is a duplicate
# Row 33496 is a duplicate
# Row 33501 is a duplicate
# Row 33502 is a duplicate
# Row 33506 is a duplicate
# Row 33507 is a duplicate
# Row 33517 is a duplicate
# Row 33519 is a duplicate
# Row 33524 is a duplicate
# Row 33527 is a duplicate
# Row 33528 is a duplicate
# Row 33532 is a duplicate
# Row 33534 is a duplicate
# Row 33535 is a duplicate
# Row 33536 is a duplicate
# Row 33536 is a duplicate
# Row 33537 is a duplicate
# Row 33539 is a duplicate
# Row 33547 is a duplicate
# Row 33556 is a duplicate
# Row 33569 is a duplicate
# Row 33574 is a duplicate
# Row 33578 is a duplicate
# Row 33598 is a duplicate
# Row 33608 is a duplicate
# Row 33682 is a duplicate
# Row 33690 is a duplicate
# Row 33694 is a duplicate
# Row 33696 is a duplicate
# Row 33699 is a duplicate
# Row 33722 is a duplicate
# Row 33736 is a duplicate
# Row 33750 is a duplicate
# Row 33774 is a duplicate
# Row 33775 is a duplicate
# Row 33779 is a duplicate
# Row 33824 is a duplicate
# Row 33830 is a duplicate
# Row 33835 is a duplicate
# Row 33842 is a duplicate
# Row 33844 is a duplicate
# Row 33850 is a duplicate
# Row 33851 is a duplicate
# Row 33870 is a duplicate
# Row 33884 is a duplicate
# Row 33894 is a duplicate
# Row 33895 is a duplicate
# Row 33905 is a duplicate
# Row 33906 is a duplicate
# Row 33913 is a duplicate
# Row 33913 is a duplicate
# Row 33924 is a duplicate
# Row 33933 is a duplicate
# Row 33944 is a duplicate
# Row 33955 is a duplicate
# Row 33957 is a duplicate
# Row 33959 is a duplicate
# Row 33959 is a duplicate
# Row 33961 is a duplicate
# Row 33966 is a duplicate
# Row 33977 is a duplicate
# Row 33988 is a duplicate
# Row 34000 is a duplicate
# Row 34001 is a duplicate
# Row 34003 is a duplicate
# Row 34055 is a duplicate
# Row 34075 is a duplicate
# Row 34081 is a duplicate
# Row 34149 is a duplicate
# Row 34150 is a duplicate
# Row 34161 is a duplicate
# Row 34169 is a duplicate
# Row 34175 is a duplicate
# Row 34188 is a duplicate
# Row 34194 is a duplicate
# Row 34196 is a duplicate
# Row 34201 is a duplicate
# Row 34213 is a duplicate
# Row 34215 is a duplicate
# Row 34217 is a duplicate
# Row 34248 is a duplicate
# Row 34248 is a duplicate
# Row 34248 is a duplicate
# Row 34256 is a duplicate
# Row 34265 is a duplicate
# Row 34271 is a duplicate
# Row 34297 is a duplicate
# Row 34302 is a duplicate
# Row 34306 is a duplicate
# Row 34332 is a duplicate
# Row 34388 is a duplicate
# Row 34406 is a duplicate
# Row 34410 is a duplicate
# Row 34412 is a duplicate
# Row 34413 is a duplicate
# Row 34417 is a duplicate
# Row 34425 is a duplicate
# Row 34427 is a duplicate
# Row 34438 is a duplicate
# Row 34454 is a duplicate
# Row 34460 is a duplicate
# Row 34460 is a duplicate
# Row 34478 is a duplicate
# Row 34480 is a duplicate
# Row 34481 is a duplicate
# Row 34481 is a duplicate
# Row 34483 is a duplicate
# Row 34484 is a duplicate
# Row 34503 is a duplicate
# Row 34528 is a duplicate
# Row 34531 is a duplicate
# Row 34536 is a duplicate
# Row 34544 is a duplicate
# Row 34546 is a duplicate
# Row 34552 is a duplicate
# Row 34572 is a duplicate
# Row 34589 is a duplicate
# Row 34592 is a duplicate
# Row 34604 is a duplicate
# Row 34614 is a duplicate
# Row 34614 is a duplicate
# Row 34629 is a duplicate
# Row 34630 is a duplicate
# Row 34634 is a duplicate
# Row 34663 is a duplicate
# Row 34670 is a duplicate
# Row 34673 is a duplicate
# Row 34692 is a duplicate
# Row 34698 is a duplicate
# Row 34711 is a duplicate
# Row 34727 is a duplicate
# Row 34737 is a duplicate
# Row 34743 is a duplicate
# Row 34743 is a duplicate
# Row 34765 is a duplicate
# Row 34766 is a duplicate
# Row 34784 is a duplicate
# Row 34789 is a duplicate
# Row 34804 is a duplicate
# Row 34832 is a duplicate
# Row 34833 is a duplicate
# Row 34836 is a duplicate
# Row 34841 is a duplicate

# %%
blocks_with_ca = gpd.GeoDataFrame(new_gdf, columns = list(blocks_with_ca.columns)) #if duplicates found, else skip

# %%
blocks_with_ca.to_file("Data/final_commarea/final_commarea.shp")
